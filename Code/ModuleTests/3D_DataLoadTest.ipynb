# %%
import sys
sys.path.append("../")

import matplotlib.pyplot as plt
import nibabel as nib
import pandas as pd
from torch.utils.data import DataLoader

from modules.Dataset import *
from modules.Utils import plot_sub, get_file_names

# %%
dataset = MRIDataset(FeTABalancedDistribution, path='../Data/feta_pro2/')

# %%
len(dataset)
# Out:
# 80

# %%
dataset.meta_data
# Out:
#    participant_id     Pathology  Gestational age
# 0         sub-001  Pathological             27.9
# 1         sub-002  Pathological             28.2
# 2         sub-003  Pathological             27.4
# 3         sub-004  Pathological             25.5
# 4         sub-005  Pathological             22.6
# ..            ...           ...              ...
# 75        sub-076  Neurotypical             23.2
# 76        sub-077  Pathological             26.9
# 77        sub-078  Pathological             24.0
# 78        sub-079  Neurotypical             29.1
# 79        sub-080  Pathological             26.9
#
# [80 rows x 3 columns]

# %%
sample = dataset[0]

# %%
sample
# Out:
# Subject(Keys: ('mri', 'mask', 'sub_id'); images: 2)

# %%
sample.sub_id
# Out:
# 'sub-001'

# %%
sample.mri.data.shape
# Out:
# torch.Size([1, 177, 207, 203])

# %%
sample.mask.data.shape
# Out:
# torch.Size([1, 177, 207, 203])

# %%
slice_idx = 88
plt.imshow(sample.mri.data[0, :, :, slice_idx], cmap='gray')
plt.show()
plt.imshow(sample.mask.data[0, :, :, slice_idx], cmap='gray')
plt.show()

# %%
mri = nib.load('../Data/feta_pro2/sub-001/anat/sub-001_rec-mial_T2w.nii.gz').get_fdata()
mask = nib.load('../Data/feta_pro2/sub-001/anat/sub-001_rec-mial_dseg.nii.gz').get_fdata()

# %%
plt.imshow(mri[:, :, slice_idx], cmap='gray')
plt.show()
plt.imshow(mask[:, :, slice_idx], cmap='gray')
plt.show()
