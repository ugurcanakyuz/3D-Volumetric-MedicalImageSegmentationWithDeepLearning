# %%
import sys
sys.path.append('../')

import gc
import torch
import torch.nn as nn
import torchsummary


import modules.models as models

# %%
data = torch.rand(1, 1, 128, 128, 128)
model = models.UNet3Dv2()
out = model(data)
assert torch.any(out)

# %%
model
# Out:
# UNet3Dv2(
#   (max_pool_2x2x2): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (down_conv_input): Conv3d(1, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#   (down_conv1): Sequential(
#     (0): Conv3d(8, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#     (1): GroupNorm(8, 32, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#     (4): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (5): ReLU(inplace=True)
#   )
#   (down_conv2): Sequential(
#     (0): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#     (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(64, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#     (4): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (5): ReLU(inplace=True)
#   )
#   (down_conv3): Sequential(
# ...

# %%
torchsummary.summary(model.to('cuda'), input_size=(1, 64, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv3d-1        [-1, 8, 64, 64, 64]             224
#             Conv3d-2       [-1, 32, 64, 64, 64]           6,944
#          GroupNorm-3       [-1, 32, 64, 64, 64]              64
#               ReLU-4       [-1, 32, 64, 64, 64]               0
#             Conv3d-5       [-1, 64, 64, 64, 64]          55,360
#          GroupNorm-6       [-1, 64, 64, 64, 64]             128
#               ReLU-7       [-1, 64, 64, 64, 64]               0
#          MaxPool3d-8       [-1, 64, 32, 32, 32]               0
#             Conv3d-9       [-1, 64, 32, 32, 32]         110,656
#         GroupNorm-10       [-1, 64, 32, 32, 32]             128
#              ReLU-11       [-1, 64, 32, 32, 32]               0
#            Conv3d-12      [-1, 128, 32, 32, 32]         221,312
#         GroupNorm-13      [-1, 128, 32, 32, 32]             256
# ...
