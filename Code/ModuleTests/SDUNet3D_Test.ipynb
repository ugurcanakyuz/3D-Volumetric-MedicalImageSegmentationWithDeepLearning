# %%
import sys
sys.path.append('../')

import torch
import torch.nn as nn
import torchsummary


import modules.models as models

# %%
data = torch.rand(1, 1, 128, 128, 128)
model = models.SDUNet3D()
out = model(data)
assert torch.any(out)

# %%
model
# Out:
# SDUNet3D(
#   (max_pool_2x2x2): MaxPool3d(kernel_size=(2, 2, 2), stride=(2, 2, 2), padding=0, dilation=1, ceil_mode=False)
#   (down_conv1): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(1, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(1, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(1, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(1, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (down_conv2): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(64, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(64, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(64, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (down_conv3): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(128, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(128, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(128, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(128, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 256, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (down_conv4): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(256, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(256, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(256, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(256, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_trans1): ConvTranspose3d(512, 512, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (up_conv1): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(1024, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(1024, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(1024, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(1024, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(1024, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 512, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_trans2): ConvTranspose3d(512, 512, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (up_conv2): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(768, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(768, 96, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(768, 48, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(768, 24, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(768, 24, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 384, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_trans3): ConvTranspose3d(384, 384, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (up_conv3): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(512, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(512, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(512, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(512, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(512, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 128, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (up_trans4): ConvTranspose3d(128, 128, kernel_size=(2, 2, 2), stride=(2, 2, 2))
#   (up_conv4): Sequential(
#     (0): DilatedBlock(
#       (conv1): Conv3d(192, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same)
#       (conv2): Conv3d(192, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(3, 3, 3))
#       (conv3): Conv3d(192, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(6, 6, 6))
#       (conv4): Conv3d(192, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(9, 9, 9))
#       (conv5): Conv3d(192, 4, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=same, dilation=(12, 12, 12))
#     )
#     (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#   )
#   (out): Conv3d(64, 8, kernel_size=(1, 1, 1), stride=(1, 1, 1))
# )

# %%
torchsummary.summary(model.to('cuda'), input_size=(1, 128, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv3d-1    [-1, 32, 128, 128, 128]             896
#             Conv3d-2    [-1, 16, 128, 128, 128]             448
#             Conv3d-3     [-1, 8, 128, 128, 128]             224
#             Conv3d-4     [-1, 4, 128, 128, 128]             112
#             Conv3d-5     [-1, 4, 128, 128, 128]             112
#       DilatedBlock-6    [-1, 64, 128, 128, 128]               0
#          GroupNorm-7    [-1, 64, 128, 128, 128]             128
#               ReLU-8    [-1, 64, 128, 128, 128]               0
#          MaxPool3d-9       [-1, 64, 64, 64, 64]               0
#            Conv3d-10       [-1, 64, 64, 64, 64]         110,656
#            Conv3d-11       [-1, 32, 64, 64, 64]          55,328
#            Conv3d-12       [-1, 16, 64, 64, 64]          27,664
#            Conv3d-13        [-1, 8, 64, 64, 64]          13,832
#            Conv3d-14        [-1, 8, 64, 64, 64]          13,832
#      DilatedBlock-15      [-1, 128, 64, 64, 64]               0
#         GroupNorm-16      [-1, 128, 64, 64, 64]             256
#              ReLU-17      [-1, 128, 64, 64, 64]               0
#         MaxPool3d-18      [-1, 128, 32, 32, 32]               0
#            Conv3d-19      [-1, 128, 32, 32, 32]         442,496
#            Conv3d-20       [-1, 64, 32, 32, 32]         221,248
#            Conv3d-21       [-1, 32, 32, 32, 32]         110,624
#            Conv3d-22       [-1, 16, 32, 32, 32]          55,312
#            Conv3d-23       [-1, 16, 32, 32, 32]          55,312
#      DilatedBlock-24      [-1, 256, 32, 32, 32]               0
#         GroupNorm-25      [-1, 256, 32, 32, 32]             512
#              ReLU-26      [-1, 256, 32, 32, 32]               0
#         MaxPool3d-27      [-1, 256, 16, 16, 16]               0
#            Conv3d-28      [-1, 256, 16, 16, 16]       1,769,728
#            Conv3d-29      [-1, 128, 16, 16, 16]         884,864
#            Conv3d-30       [-1, 64, 16, 16, 16]         442,432
#            Conv3d-31       [-1, 32, 16, 16, 16]         221,216
#            Conv3d-32       [-1, 32, 16, 16, 16]         221,216
#      DilatedBlock-33      [-1, 512, 16, 16, 16]               0
#         GroupNorm-34      [-1, 512, 16, 16, 16]           1,024
#              ReLU-35      [-1, 512, 16, 16, 16]               0
#         MaxPool3d-36         [-1, 512, 8, 8, 8]               0
#   ConvTranspose3d-37      [-1, 512, 16, 16, 16]       2,097,664
#            Conv3d-38      [-1, 256, 16, 16, 16]       7,078,144
#            Conv3d-39      [-1, 128, 16, 16, 16]       3,539,072
#            Conv3d-40       [-1, 64, 16, 16, 16]       1,769,536
#            Conv3d-41       [-1, 32, 16, 16, 16]         884,768
#            Conv3d-42       [-1, 32, 16, 16, 16]         884,768
#      DilatedBlock-43      [-1, 512, 16, 16, 16]               0
#         GroupNorm-44      [-1, 512, 16, 16, 16]           1,024
#              ReLU-45      [-1, 512, 16, 16, 16]               0
#   ConvTranspose3d-46      [-1, 512, 32, 32, 32]       2,097,664
#            Conv3d-47      [-1, 192, 32, 32, 32]       3,981,504
#            Conv3d-48       [-1, 96, 32, 32, 32]       1,990,752
#            Conv3d-49       [-1, 48, 32, 32, 32]         995,376
#            Conv3d-50       [-1, 24, 32, 32, 32]         497,688
#            Conv3d-51       [-1, 24, 32, 32, 32]         497,688
#      DilatedBlock-52      [-1, 384, 32, 32, 32]               0
#         GroupNorm-53      [-1, 384, 32, 32, 32]             768
#              ReLU-54      [-1, 384, 32, 32, 32]               0
#   ConvTranspose3d-55      [-1, 384, 64, 64, 64]       1,180,032
#            Conv3d-56       [-1, 64, 64, 64, 64]         884,800
#            Conv3d-57       [-1, 32, 64, 64, 64]         442,400
#            Conv3d-58       [-1, 16, 64, 64, 64]         221,200
#            Conv3d-59        [-1, 8, 64, 64, 64]         110,600
#            Conv3d-60        [-1, 8, 64, 64, 64]         110,600
#      DilatedBlock-61      [-1, 128, 64, 64, 64]               0
#         GroupNorm-62      [-1, 128, 64, 64, 64]             256
#              ReLU-63      [-1, 128, 64, 64, 64]               0
#   ConvTranspose3d-64   [-1, 128, 128, 128, 128]         131,200
#            Conv3d-65    [-1, 32, 128, 128, 128]         165,920
#            Conv3d-66    [-1, 16, 128, 128, 128]          82,960
#            Conv3d-67     [-1, 8, 128, 128, 128]          41,480
#            Conv3d-68     [-1, 4, 128, 128, 128]          20,740
#            Conv3d-69     [-1, 4, 128, 128, 128]          20,740
#      DilatedBlock-70    [-1, 64, 128, 128, 128]               0
#         GroupNorm-71    [-1, 64, 128, 128, 128]             128
#              ReLU-72    [-1, 64, 128, 128, 128]               0
#            Conv3d-73     [-1, 8, 128, 128, 128]             520
# ================================================================
# Total params: 34,379,464
# Trainable params: 34,379,464
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 8.00
# Forward/backward pass size (MB): 14266.00
# Params size (MB): 131.15
# Estimated Total Size (MB): 14405.15
# ----------------------------------------------------------------
